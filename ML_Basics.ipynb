# %% [markdown]
# <a href="https://colab.research.google.com/github/biswa2005/ML-Learning/blob/main/ML_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###EDA(Exploitory Data Analysis)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('insurance.csv')

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
numeric_columns = df.select_dtypes(include=['int64', 'float64'] ).columns

# %%
for cols in numeric_columns :
  plt.figure(figsize=(6,4))
  sns.histplot(x = df[cols], kde=True, bins=20)

# %%
sns.countplot(x = df['children'])
# Out:
# <Axes: xlabel='children', ylabel='count'>

# %%
sns.countplot(x = df['sex'])
sns.countplot(x = df['smoker'])
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
for cols in numeric_columns :
  plt.figure(figsize=(6,4))
  sns.boxplot(x = df[cols])

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ###Data Preprocessing & Cleaning

# %%
df_refined = df.copy()
df_refined
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df_refined['sex'] = df_refined['sex'].replace({'male' : 0, 'female' : 1})
df_refined.head()
# Out:
# /tmp/ipython-input-858846172.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_refined['sex'] = df_refined['sex'].replace({'male' : 0, 'female' : 1})
#    age  sex     bmi  children smoker     region      charges
# 0   19    1  27.900         0    yes  southwest  16884.92400
# 1   18    0  33.770         1     no  southeast   1725.55230
# 2   28    0  33.000         3     no  southeast   4449.46200
# 3   33    0  22.705         0     no  northwest  21984.47061
# 4   32    0  28.880         0     no  northwest   3866.85520

# %%
df_refined['smoker'] = df_refined['smoker'].replace({'yes' : 1, 'no' : 0})
df_refined.head()
# Out:
# /tmp/ipython-input-2496613788.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_refined['smoker'] = df_refined['smoker'].replace({'yes' : 1, 'no' : 0})
#    age  sex     bmi  children  smoker     region      charges
# 0   19    1  27.900         0       1  southwest  16884.92400
# 1   18    0  33.770         1       0  southeast   1725.55230
# 2   28    0  33.000         3       0  southeast   4449.46200
# 3   33    0  22.705         0       0  northwest  21984.47061
# 4   32    0  28.880         0       0  northwest   3866.85520

# %%
df_refined.rename(columns = {
    'sex' : 'is_female',
    'smoker' : 'is_smoker'
}, inplace = True)

df_refined.head()
# Out:
#    age  is_female     bmi  children  is_smoker     region      charges
# 0   19          1  27.900         0          1  southwest  16884.92400
# 1   18          0  33.770         1          0  southeast   1725.55230
# 2   28          0  33.000         3          0  southeast   4449.46200
# 3   33          0  22.705         0          0  northwest  21984.47061
# 4   32          0  28.880         0          0  northwest   3866.85520

# %%
# One Hot Enoding

df_refined = pd.get_dummies(df_refined, columns=['region'], dtype='int64', drop_first=-True)

# %%
df_refined.head()
# Out:
#    age  is_female     bmi  children  is_smoker      charges  region_northwest  \
# 0   19          1  27.900         0          1  16884.92400                 0
# 1   18          0  33.770         1          0   1725.55230                 0
# 2   28          0  33.000         3          0   4449.46200                 0
# 3   33          0  22.705         0          0  21984.47061                 1
# 4   32          0  28.880         0          0   3866.85520                 1
#
#    region_southeast  region_southwest
# 0                 0                 1
# 1                 1                 0
# 2                 1                 0
# 3                 0                 0
# 4                 0                 0

# %% [markdown]
# ###Feature Engineering & Extraction

# %%
df_refined['bmi_category'] = pd.cut(
    df_refined['bmi'],
    bins = [0 , 18.5, 24.9, 29.9, float('inf')],
    labels =['Underweight', 'Healthy', 'Overweight', 'Obese']
    )
df_refined.head()
# Out:
#    age  is_female     bmi  children  is_smoker      charges  region_northwest  \
# 0   19          1  27.900         0          1  16884.92400                 0
# 1   18          0  33.770         1          0   1725.55230                 0
# 2   28          0  33.000         3          0   4449.46200                 0
# 3   33          0  22.705         0          0  21984.47061                 1
# 4   32          0  28.880         0          0   3866.85520                 1
#
#    region_southeast  region_southwest bmi_category
# 0                 0                 1   Overweight
# 1                 1                 0        Obese
# 2                 1                 0        Obese
# 3                 0                 0      Healthy
# 4                 0                 0   Overweight

# %%
df_refined = pd.get_dummies(df_refined, columns=['bmi_category'], dtype='int64', drop_first=-True)
df_refined.head()
# Out:
#    age  is_female     bmi  children  is_smoker      charges  region_northwest  \
# 0   19          1  27.900         0          1  16884.92400                 0
# 1   18          0  33.770         1          0   1725.55230                 0
# 2   28          0  33.000         3          0   4449.46200                 0
# 3   33          0  22.705         0          0  21984.47061                 1
# 4   32          0  28.880         0          0   3866.85520                 1
#
#    region_southeast  region_southwest  bmi_category_Healthy  \
# 0                 0                 1                     0
# 1                 1                 0                     0
# 2                 1                 0                     0
# 3                 0                 0                     1
# 4                 0                 0                     0
#
#    bmi_category_Overweight  bmi_category_Obese
# 0                        1                   0
# ...

# %%
from sklearn.preprocessing import StandardScaler
cols = ['age', 'bmi', 'children']

scaler = StandardScaler()
df_refined[cols] = scaler.fit_transform(df[cols])
df_refined.head()
# Out:
#         age  is_female       bmi  children  is_smoker      charges  \
# 0 -1.438764          1 -0.453320 -0.908614          1  16884.92400
# 1 -1.509965          0  0.509621 -0.078767          0   1725.55230
# 2 -0.797954          0  0.383307  1.580926          0   4449.46200
# 3 -0.441948          0 -1.305531 -0.908614          0  21984.47061
# 4 -0.513149          0 -0.292556 -0.908614          0   3866.85520
#
#    region_northwest  region_southeast  region_southwest  bmi_category_Healthy  \
# 0                 0                 0                 1                     0
# 1                 0                 1                 0                     0
# 2                 0                 1                 0                     0
# 3                 1                 0                 0                     1
# 4                 1                 0                 0                     0
#
#    bmi_category_Overweight  bmi_category_Obese
# ...
