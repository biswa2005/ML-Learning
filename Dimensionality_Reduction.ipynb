# %% [markdown]
# <a href="https://colab.research.google.com/github/biswa2005/ML-Learning/blob/main/Dimensionality_Reduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###PCA (Principal Component Analysis)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
X, y = make_blobs(n_samples=500, n_features=5, centers=3, cluster_std=1.5, random_state=42)

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# %%
df_pca = pd.DataFrame(X_pca, columns=['feat_1', 'feat_2'])

# %%
df_pca = pd.DataFrame(X_pca, columns=['feat_1', 'feat_2'])
df_pca['label'] = y
sns.scatterplot(data=df_pca, x='feat_1', y='feat_2', hue='label', palette='tab10')
# Out:
# <Axes: xlabel='feat_1', ylabel='feat_2'>
